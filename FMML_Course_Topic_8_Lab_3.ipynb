# %% [markdown]
# <a href="https://colab.research.google.com/github/Gopi811/FMML-Course-Assignments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-25 08:55:19--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  46.2MB/s    in 1.5s
#
# 2024-04-25 08:55:24 (46.2 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26637  1611.05424v2  We introduce associative embedding, a novel me...    cs
# 22514  1610.06545v4  The goal of two-sample tests is to assess whet...  stat
# 22420  1606.05273v1  Regression trees are becoming increasingly pop...  stat
# 6843   1706.06978v2  To better extract users' interest by exploitin...  stat
# 22563  1701.00422v2  Personalized treatment of patients based on ti...  stat
# ...             ...                                                ...   ...
# 31020  1802.01445v1  Remote sensing is extensively used in cartogra...    cs
# 19589   1001.2277v1  Many engineering optimization problems can be ...    cs
# 36983  1602.01718v1  The coordination of multiple autonomous vehicl...    cs
# 35332  cs/0405107v1  In the last years, there has been an increasin...    cs
# 7684   1802.08250v1  Lifelong learning aims to develop machine lear...    cs
#
#                                                    title  year  \
# 26637  Associative Embedding: End-to-End Learning for...  2016
# 22514             Revisiting Classifier Two-Sample Tests  2016
# 22420  The Effect of Heteroscedasticity on Regression...  2016
# 6843   Deep Interest Network for Click-Through Rate P...  2017
# 22563  Towards multiple kernel principal component an...  2017
# ...                                                  ...   ...
# 31020  Road Segmentation in SAR Satellite Images with...  2018
# 19589  Application of a Fuzzy Programming Technique t...  2010
# 36983  Formal Verification of Autonomous Vehicle Plat...  2016
# 35332  A Framework for Combining Defeasible Argumenta...  2004
# 7684   Overcoming Catastrophic Forgetting in Convolut...  2018
#
#                                                 keywords
# 26637  [introduce, associative, embedding, supervisin...
# 22514  [distribution, intriguingly, relatively, unexp...
# 22420  [regression, increasingly, predicting, statist...
# 6843   [exploiting, historical, prediction, advertisi...
# 22563  [personalized, treatment, increased, therapies...
# ...                                                  ...
# 31020  [extensively, cartography, transportation, ext...
# 19589  [engineering, optimization, considered, progra...
# 36983  [coordination, autonomous, autonomous, behavio...
# 35332  [increasing, applications, deductive, develope...
# 7684   [preserving, performance, autonomous, knowledg...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26637    [introduce, associative, embedding, supervisin...
# 22514    [distribution, intriguingly, relatively, unexp...
# 22420    [regression, increasingly, predicting, statist...
# 6843     [exploiting, historical, prediction, advertisi...
# 22563    [personalized, treatment, increased, therapies...
#                                ...
# 26841    [introduces, generating, synchronized, recurre...
# 211      [challenge, development, computational, algori...
# 22218    [optimization, efficient, optimization, hyperp...
# 6333     [efficient, algorithm, collaborative, preferen...
# 6978     [introduce, conditional, generative, supervise...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8741 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a470555d-4ae3-4c7b-b7cd-e3e21a0bbe86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a470555d-4ae3-4c7b-b7cd-e3e21a0bbe86")) {                    Plotly.newPlot(                        "a470555d-4ae3-4c7b-b7cd-e3e21a0bbe86",                        [{"x":["associative","predictions","introduce","estimation","architecture","detection","including","pipelines","detections","performance","integrated","embedding","supervising","convolutional","segmentation","simultaneously","technique","assignments","classifier","application","intriguingly","classification","likelihoods","particular","construct","properties","relatively","predictive","generative","statistics","classifiers","revisiting","theoretical","representation","adversarial","intractable","establish","unexplored","interpret","uncertainty","discovery","alternatives","hypothesis","distribution","interpretable","accurately","statistical","implicitly","applications","structure","splitting","specifying","locations","ensembles","adversely","heteroscedasticity","simulation","regression","homogeneous","heteroscedastic","predicting","algorithm","prediction","meaningful","explanatory","increasingly","popularity","influenced","effective","activation","overfitting","industrial","historical","carefully","outperforms","advertising","developed","represents","observations","candidate","encounter","different","regularization","interested","attention","according","capturing","significantly","exploiting","interests","traditional","structures","expression","information","subsequent","techniques","principal","personalized","unsupervised","extension","integration","treatment","visualizing","demonstrate","usability","determine","clustering","unfortunately","individual","identification","therefore","diagnosed","parameters","therapies","methodology","advantages","component","integrative","increased","isolation","generality","artifacts","discriminating","disciplines","anticipate","solutions","significant","inhomogeneity","equalization","explaining","experiments","theoretically","important","empirically","principled","previously","illustrate","limitations","essentially","conditions","histogram","synthetic","understanding","similarity","practically","equivalent","discovered","objectives","especially","comparing","demonstrated","advantage","sensitivity","challenging","approaches","cognitively","sensitive","biomarkers","structural","assessing","delineating","algorithms","considered","investigations","modalities","investigated","extraction","practical","impairment","diagnosis","specificity","discriminant","cognitive","progression","dimensional","alzheimers","recognition","automated","exploration","accuracies","consideration","conditional","architectures","competitive","combination","analogous","initialize","unavailability","consistent","formulate","independently","improvements","optimizing","sufficient","representations","discriminative","effectiveness","auxiliary","meanwhile","effectively"],"y":[12,99,304,219,219,374,253,11,21,874,59,117,4,334,211,103,266,11,149,231,4,523,2,263,95,196,57,61,116,62,129,9,157,356,106,20,36,7,18,75,44,17,42,219,33,58,164,21,416,350,8,9,38,14,4,1,74,126,23,1,89,831,236,50,5,59,19,6,235,37,23,15,23,30,269,9,213,46,67,44,3,757,79,29,166,103,48,284,82,16,168,151,52,669,20,377,37,16,125,81,57,42,13,579,8,77,157,25,132,95,134,2,273,0,67,83,100,1,48,14,13,28,4,5,5,146,230,2,4,25,605,48,379,88,17,80,79,70,27,151,14,142,158,155,10,54,21,23,118,71,105,93,40,251,412,1,61,0,74,11,1,624,146,6,30,53,132,142,3,51,15,31,56,4,187,4,353,105,44,21,18,100,115,117,131,10,3,2,83,56,42,114,44,67,230,84,221,19,21,126],"type":"bar"},{"x":["associative","predictions","introduce","estimation"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8125

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3125);'>Redundancy</span> <span style=''>in</span> <span style=''>Logic</span> <span style=''>I</span> <span style=''>CNF</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Propositional</span> <span style=''>Formulae</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.342685370741483);'>knowledge</span> <span style=''>base</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>redundant</span> <span style=''>if</span> <span style=''>it</span> <span style=''>contains</span> <span style=''>parts</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>inferred</span> <span style=''>from</span> <span style=''>the</span> <span style=''>rest</span> <span style=''>of</span> <span style=''>it</span> <span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>checking</span> <span style=''>whether</span> <span style=''>a</span> <span style=''>CNF</span> <span style=''>formula</span> <span style=''>(a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>clauses)</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>redundant</span> <span style=''>that</span> <span style=''>is</span> <span style=''>it</span> <span style=''>contains</span> <span style=''>clauses</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>the</span> <span style=''>other</span> <span style=''>ones</span> <span style=''>Any</span> <span style=''>CNF</span> <span style=''>formula</span> <span style=''>can</span> <span style=''>be</span> <span style=''>made</span> <span style=''>irredundant</span> <span style=''>by</span> <span style=''>deleting</span> <span style=''>some</span> <span style=''>of</span> <span style=''>its</span> <span style=''>clauses</span> <span style=''>what</span> <span style=''>results</span> <span style=''>is</span> <span style=''>an</span> <span style=''>irredundant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style=''>subset</span> <span style=''>(IES)</span> <span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>some</span> <span style=''>related</span> <span style=''>problems</span> <span style='background-color:rgba(0, 255, 0, 0.9661016949152543);'>verification</span> <span style=''>checking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>IES</span> <span style=''>with</span> <span style=''>a</span> <span style=''>given</span> <span style=''>size</span> <span style=''>checking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>necessary</span> <span style=''>and</span> <span style=''>possible</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>clauses</span> <span style=''>in</span> <span style=''>IESs</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uniqueness</span> <span style=''>We</span> <span style=''>also</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3125);'>redundancy</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.32923617208077266);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923076);'>definitions</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalence</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Post</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>Prior</span> <span style=''>Swapping</span> <br/><br/><span style=''>While</span> <span style=''>Bayesian</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>praised</span> <span style=''>for</span> <span style=''>their</span> <span style=''>ability</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>useful</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>in</span> <span style=''>practice</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convenient</span> <span style=''>priors</span> <span style=''>that</span> <span style=''>allow</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style=''>cheap</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>are</span> <span style=''>commonly</span> <span style=''>used</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style=''>question</span> <span style=''>for</span> <span style=''>a</span> <span style=''>given</span> <span style=''>model</span> <span style=''>is</span> <span style=''>it</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>result</span> <span style=''>with</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convenient</span> <span style=''>false</span> <span style=''>prior</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>afterwards</span> <span style=''>given</span> <span style=''>any</span> <span style=''>target</span> <span style=''>prior</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>quickly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>this</span> <span style=''>result</span> <span style=''>into</span> <span style=''>the</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>solution</span> <span style=''>is</span> <span style=''>to</span> <span style=''>use</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style=''>(IS)</span> <span style=''>However</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>IS</span> <span style=''>will</span> <span style=''>fail</span> <span style=''>for</span> <span style=''>many</span> <span style=''>choices</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>depending</span> <span style=''>on</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>form</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>to</span> <span style=''>the</span> <span style=''>false</span> <span style=''>prior</span> <span style=''>Instead</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>prior</span> <span style=''>swapping</span> <span style=''>a</span> <span style=''>method</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style='background-color:rgba(255, 0, 0, 0.34975369458128086);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>with</span> <span style=''>Multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Objectives</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>and</span> <span style=''>solve</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.34975369458128086);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objectives</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>many</span> <span style=''>real</span> <span style=''>world</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>We</span> <span style=''>first</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projection</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>attains</span> <span style=''>an</span> <span style=''>O(T</span> <span style=''>13)</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>convergence</span> <span style=''>rate</span> <span style=''>Then</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leveraging</span> <span style=''>on</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Lagrangian</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constrained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>we</span> <span style=''>devise</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>primal</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.34975369458128086);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>attains</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>convergence</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>O(T</span> <span style=''>12)</span> <span style=''>for</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.36000000000000004);'>Lipschitz</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objectives</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>unifying</span> <span style=''>view</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>measures</span> <span style=''>in</span> <span style=''>multi</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <br/><br/><span style=''>In</span> <span style=''>the</span> <span style=''>last</span> <span style=''>few</span> <span style=''>years</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>measures</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>to</span> <span style=''>overcome</span> <span style=''>the</span> <span style=''>weakness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style=''>natural</span> <span style=''>metric</span> <span style=''>the</span> <span style=''>Accuracy</span> <span style=''>Among</span> <span style=''>them</span> <span style=''>Matthews</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Correlation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Coefficient</span> <span style=''>has</span> <span style=''>recently</span> <span style=''>gained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>popularity</span> <span style=''>among</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researchers</span> <span style=''>not</span> <span style=''>only</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>but</span> <span style=''>also</span> <span style=''>in</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>fields</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bioinformatics</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonetheless</span> <span style=''>further</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>are</span> <span style=''>being</span> <span style=''>proposed</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Confusion</span> <span style=''>Entropy</span> <span style=''>a</span> <span style=''>recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>measure</span> <span style=''>for</span> <span style=''>multi</span> <span style=''>class</span> <span style=''>problems</span> <span style=''>has</span> <span style=''>a</span> <span style=''>strong</span> <span style=''>(monotone)</span> <span style=''>relation</span> <span style=''>with</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style=''>metric</span> <span style=''>the</span> <span style=''>Matthews</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Correlation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Coefficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computational</span> <span style=''>evidence</span> <span style=''>in</span> <span style=''>support</span> <span style=''>of</span> <span style=''>the</span> <span style=''>claim</span> <span style='' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10257326661901359)
# 	evaluation (0.10257326661901359)
# 	information (0.23909935668334525)
# 	experimental (0.13831308077197998)
# 	representation (0.1272337383845604)
# 	segmentation (0.07541100786275912)
# 	convolutional (0.11937097927090778)
# 	different (0.2705503931379557)
# 	detection (0.13366690493209435)
# 	recognition (0.1261615439599714)
#
# Some Statistics words are:
# 	variational (0.1063936063936064)
# 	stochastic (0.13686313686313686)
# 	statistical (0.15334665334665334)
# 	variables (0.14235764235764237)
# 	theoretical (0.15634365634365635)
# 	algorithm (0.3986013986013986)
# 	dimensional (0.17632367632367632)
# 	distribution (0.1903096903096903)
# 	inference (0.2037962037962038)
# 	regression (0.1958041958041958)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="670b8bf9-dc58-421b-a331-a39defd21b6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("670b8bf9-dc58-421b-a331-a39defd21b6e")) {                    Plotly.newPlot(                        "670b8bf9-dc58-421b-a331-a39defd21b6e",                        [{"x":["associative","predictions","introduce","estimation","architecture","detection","including","pipelines","detections","performance","integrated","embedding","supervising","convolutional","segmentation","simultaneously","technique","assignments","classifier","application","intriguingly","classification","likelihoods","particular","construct","properties","relatively","predictive","generative","statistics","classifiers","revisiting","theoretical","representation","adversarial","intractable","establish","unexplored","interpret","uncertainty","discovery","alternatives","hypothesis","distribution","interpretable","accurately","statistical","implicitly","applications","structure","splitting","specifying","locations","ensembles","adversely","heteroscedasticity","simulation","regression","homogeneous","heteroscedastic","predicting","algorithm","prediction","meaningful","explanatory","increasingly","popularity","influenced","effective","activation","overfitting","industrial","historical","carefully","outperforms","advertising","developed","represents","observations","candidate","encounter","different","regularization","interested","attention","according","capturing","significantly","exploiting","interests","traditional","structures","expression","information","subsequent","techniques","principal","personalized","unsupervised","extension","integration","treatment","visualizing","demonstrate","usability","determine","clustering","unfortunately","individual","identification","therefore","diagnosed","parameters","therapies","methodology","advantages","component","integrative","increased","isolation","generality","artifacts","discriminating","disciplines","anticipate","solutions","significant","inhomogeneity","equalization","explaining","experiments","theoretically","important","empirically","principled","previously","illustrate","limitations","essentially","conditions","histogram","synthetic","understanding","similarity","practically","equivalent","discovered","objectives","especially","comparing","demonstrated","advantage","sensitivity","challenging","approaches","cognitively","sensitive","biomarkers","structural","assessing","delineating","algorithms","considered","investigations","modalities","investigated","extraction","practical","impairment","diagnosis","specificity","discriminant","cognitive","progression","dimensional","alzheimers","recognition","automated","exploration","accuracies","consideration","conditional","architectures","competitive","combination","analogous","initialize","unavailability","consistent","formulate","independently","improvements","optimizing","sufficient","representations","discriminative","effectiveness","auxiliary","meanwhile","effectively","representative","encourages","sequential","structured","guarantees","definiteness","operators","simulations","appropriately","generalization","following","generalize","exponentiated","presented","decompositions","completion","construction","measurements","influence","framework","divergence","variational","bernoulli","initialization","highlight","statistic","constrains","objective","inference","consequently","flexibility","annealing","consistently","posterior","optimization","autoencoder","designing","deterministic","approximate","proximity","capabilities","alternative","functions","likelihood","statistically","directions","complementary","exploring","rectangles","efficient","breakthrough","unprecedented","invest ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	therapies
# 	biomarkers
# 	emphdirectly
# 	deconvnet
# 	biomarker
# 	transplantation
# 	disentangles
# 	mcallester
# 	distributionally
# 	adaboosts
# 	normalisation
# 	lengthscales
# 	composers
# 	encapsulate
# 	tibshirani
# 	criterions
# 	layerwise
# 	informations
# 	semiparametric
# 	circumvents
# Some words which never appear in Statistics papers:
# 	prerequisite
# 	arrangement
# 	sharpening
# 	attenuation
# 	plagiarism
# 	inevitably
# 	terminologies
# 	conforming
# 	illumination
# 	formalizing
# 	ontologies
# 	delivering
# 	delineations
# 	engineers
# 	suggestive
# 	automaton
# 	instructions
# 	sensorimotor
# 	anticipation
# 	mirroring

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.073518564052127e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7791666666666667
